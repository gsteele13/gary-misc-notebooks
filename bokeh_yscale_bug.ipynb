# %%
import numpy as np

from bokeh.models import ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.io import output_notebook, push_notebook
from bokeh.models import LogScale, LinearScale


# This will import the latest compatible bokeh JS from the CDN
output_notebook()

# Generate data
x = np.linspace(0,100,1000)
y = 1/((x-50)**2 + 1) 
y += np.random.normal(size=len(x))*0.01
y += 1/((x-80)**2 + 5)

# Plot it
p = figure(height=200, width=600) 
p.sizing_mode = "scale_width"
p.line(x,y)
# If uncommented, this does work
# p.y_scale = LogScale()
target = show(p, notebook_handle=True)

# But this does nothing
p.y_scale = LogScale()
push_notebook(handle=target)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2515">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="c99b6401-cad6-42a6-bc21-40393ecb79fc" data-root-id="2516"></div>

# %%
# !bokeh info
# Out:
# Python version      :  3.9.7 (default, Sep 16 2021, 08:50:36)
# IPython version     :  7.29.0
# Tornado version     :  6.1
# Bokeh version       :  2.4.2
# BokehJS static path :  /Users/gsteele/anaconda3/envs/jan2022/lib/python3.9/site-packages/bokeh/server/static
# node.js version     :  (not installed)
# npm version         :  (not installed)
# Operating system    :  macOS-10.16-x86_64-i386-64bit

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 7.29.0
# ipykernel        : 6.4.1
# ipywidgets       : 7.6.5
# jupyter_client   : 7.1.0
# jupyter_core     : 4.9.1
# jupyter_server   : not installed
# jupyterlab       : not installed
# nbclient         : 0.5.3
# nbconvert        : 6.3.0
# nbformat         : 5.1.3
# notebook         : 6.4.6
# qtconsole        : 5.1.1
# traitlets        : 5.1.1
